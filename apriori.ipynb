# %%
# apriori implementation example
import pandas as pd
import numpy as np
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
# read the dataset
data = pd.read_csv('../market_basket_example.csv')

# shape of dataset
data.shape
# Out:
# (7500, 20)

# %%
data.head()
# Out:
#            shrimp    almonds     avocado    vegetables mix green grapes  \
# 0         burgers  meatballs        eggs               NaN          NaN
# 1         chutney        NaN         NaN               NaN          NaN
# 2          turkey    avocado         NaN               NaN          NaN
# 3   mineral water       milk  energy bar  whole wheat rice    green tea
# 4  low fat yogurt        NaN         NaN               NaN          NaN
#
#   whole weat flour yams cottage cheese energy drink tomato juice  \
# 0              NaN  NaN            NaN          NaN          NaN
# 1              NaN  NaN            NaN          NaN          NaN
# 2              NaN  NaN            NaN          NaN          NaN
# 3              NaN  NaN            NaN          NaN          NaN
# 4              NaN  NaN            NaN          NaN          NaN
#
#   low fat yogurt green tea honey salad mineral water salmon antioxydant juice  \
# 0            NaN       NaN   NaN   NaN           NaN    NaN               NaN
# 1            NaN       NaN   NaN   NaN           NaN    NaN               NaN
# 2            NaN       NaN   NaN   NaN           NaN    NaN               NaN
# 3            NaN       NaN   NaN   NaN           NaN    NaN               NaN
# 4            NaN       NaN   NaN   NaN           NaN    NaN               NaN
#
#   frozen smoothie spinach  olive oil
# 0             NaN     NaN        NaN
# 1             NaN     NaN        NaN
# 2             NaN     NaN        NaN
# 3             NaN     NaN        NaN
# 4             NaN     NaN        NaN

# %%
# checking the random entries in the data

data.sample(10)
# Out:
#            shrimp               almonds    avocado vegetables mix  \
# 2153         milk                  eggs  champagne            NaN
# 930     champagne                   NaN        NaN            NaN
# 1887     red wine         mineral water    muffins       pancakes
# 2143    spaghetti         mineral water  olive oil  strong cheese
# 3394       butter  extra dark chocolate        NaN            NaN
# 4607    chocolate                  milk  olive oil            NaN
# 672          yams         mineral water       eggs           cake
# 1558         eggs       frozen smoothie        NaN            NaN
# 2531         soup                   NaN        NaN            NaN
# 1183  protein bar                   NaN        NaN            NaN
#
#      green grapes whole weat flour         yams    cottage cheese  \
# 2153          NaN              NaN          NaN               NaN
# 930           NaN              NaN          NaN               NaN
# 1887        honey             cake  cooking oil  whole weat flour
# 2143        honey          cereals    chocolate               NaN
# 3394          NaN              NaN          NaN               NaN
# 4607          NaN              NaN          NaN               NaN
# 672           NaN              NaN          NaN               NaN
# 1558          NaN              NaN          NaN               NaN
# 2531          NaN              NaN          NaN               NaN
# 1183          NaN              NaN          NaN               NaN
#
#       energy drink     tomato juice        low fat yogurt green tea  \
# 2153           NaN              NaN                   NaN       NaN
# 930            NaN              NaN                   NaN       NaN
# 1887  french fries  frozen smoothie  mushroom cream sauce  hot dogs
# 2143           NaN              NaN                   NaN       NaN
# 3394           NaN              NaN                   NaN       NaN
# 4607           NaN              NaN                   NaN       NaN
# 672            NaN              NaN                   NaN       NaN
# 1558           NaN              NaN                   NaN       NaN
# 2531           NaN              NaN                   NaN       NaN
# 1183           NaN              NaN                   NaN       NaN
#
#                 honey      salad mineral water salmon antioxydant juice  \
# 2153              NaN        NaN           NaN    NaN               NaN
# 930               NaN        NaN           NaN    NaN               NaN
# 1887  sparkling water  green tea           NaN    NaN               NaN
# 2143              NaN        NaN           NaN    NaN               NaN
# 3394              NaN        NaN           NaN    NaN               NaN
# 4607              NaN        NaN           NaN    NaN               NaN
# 672               NaN        NaN           NaN    NaN               NaN
# 1558              NaN        NaN           NaN    NaN               NaN
# 2531              NaN        NaN           NaN    NaN               NaN
# 1183              NaN        NaN           NaN    NaN               NaN
#
#      frozen smoothie spinach  olive oil
# 2153             NaN     NaN        NaN
# 930              NaN     NaN        NaN
# 1887             NaN     NaN        NaN
# 2143             NaN     NaN        NaN
# 3394             NaN     NaN        NaN
# 4607             NaN     NaN        NaN
# 672              NaN     NaN        NaN
# 1558             NaN     NaN        NaN
# 2531             NaN     NaN        NaN
# 1183             NaN     NaN        NaN

# %%
# preprocessing
# making each customers shopping items an identical list
trans = []
for i in range(0, 7501):
    trans.append([str(data.values[i,j]) for j in range(0, 20)])

# conveting it into an numpy array
trans = np.array(trans)

# checking the shape of the array
print(trans.shape)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-02c9fcb91d3a> in <module>
#       3 trans = []
#       4 for i in range(0, 7501):
# ----> 5     trans.append([str(data.values[i,j]) for j in range(0, 20)])
#       6
#       7 # conveting it into an numpy array
#
# <ipython-input-5-02c9fcb91d3a> in <listcomp>(.0)
#       3 trans = []
#       4 for i in range(0, 7501):
# ----> 5     trans.append([str(data.values[i,j]) for j in range(0, 20)])
#       6
#       7 # conveting it into an numpy array
#
# IndexError: index 7500 is out of bounds for axis 0 with size 7500

# %%
# using transacton encoder
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
data = te.fit_transform(trans)
data = pd.DataFrame(data, columns = te.columns_)

# getting the shape of the data
data.shape
# Out:
# (7500, 121)

# %%
# getting correlations for 121 items would be messy 
# so let's reduce the items from 121 to 50

data = data.loc[:, ['mineral water', 'burgers', 'turkey', 'chocolate', 'frozen vegetables', 'spaghetti',
                    'shrimp', 'grated cheese', 'eggs', 'cookies', 'french fries', 'herb & pepper', 'ground beef',
                    'tomatoes', 'milk', 'escalope', 'fresh tuna', 'red wine', 'ham', 'cake', 'green tea',
                    'whole wheat pasta', 'pancakes', 'soup', 'muffins', 'energy bar', 'olive oil', 'champagne', 
                    'avocado', 'pepper', 'butter', 'parmesan cheese', 'whole wheat rice', 'low fat yogurt', 
                    'chicken', 'vegetables mix', 'pickles', 'meatballs', 'frozen smoothie', 'yogurt cake']]

# checking the shape
data.shape
# Out:
# (7500, 40)

# %%
# columns
data.columns
# Out:
# Index(['mineral water', 'burgers', 'turkey', 'chocolate', 'frozen vegetables',
#        'spaghetti', 'shrimp', 'grated cheese', 'eggs', 'cookies',
#        'french fries', 'herb & pepper', 'ground beef', 'tomatoes', 'milk',
#        'escalope', 'fresh tuna', 'red wine', 'ham', 'cake', 'green tea',
#        'whole wheat pasta', 'pancakes', 'soup', 'muffins', 'energy bar',
#        'olive oil', 'champagne', 'avocado', 'pepper', 'butter',
#        'parmesan cheese', 'whole wheat rice', 'low fat yogurt', 'chicken',
#        'vegetables mix', 'pickles', 'meatballs', 'frozen smoothie',
#        'yogurt cake'],
#       dtype='object')

# %%
data.head()
# Out:
#    mineral water  burgers  turkey  chocolate  frozen vegetables  spaghetti  \
# 0          False     True   False      False              False      False
# 1          False    False   False      False              False      False
# 2          False    False    True      False              False      False
# 3           True    False   False      False              False      False
# 4          False    False   False      False              False      False
#
#    shrimp  grated cheese   eggs  cookies  ...  butter  parmesan cheese  \
# 0   False          False   True    False  ...   False            False
# 1   False          False  False    False  ...   False            False
# 2   False          False  False    False  ...   False            False
# 3   False          False  False    False  ...   False            False
# 4   False          False  False    False  ...   False            False
#
#    whole wheat rice  low fat yogurt  chicken  vegetables mix  pickles  \
# 0             False           False    False           False    False
# 1             False           False    False           False    False
# 2             False           False    False           False    False
# 3              True           False    False           False    False
# 4             False            True    False           False    False
#
#    meatballs  frozen smoothie  yogurt cake
# 0       True            False        False
# 1      False            False        False
# 2      False            False        False
# 3      False            False        False
# 4      False            False        False
#
# [5 rows x 40 columns]

# %%
# applying apriori with minimum support of 5 %
apriori(data, min_support = 0.01, use_colnames = True)
# Out:
#       support                            itemsets
# 0    0.238267                     (mineral water)
# 1    0.087200                           (burgers)
# 2    0.062533                            (turkey)
# 3    0.163867                         (chocolate)
# 4    0.095333                 (frozen vegetables)
# ..        ...                                 ...
# 206  0.010133  (eggs, mineral water, ground beef)
# 207  0.013067         (eggs, mineral water, milk)
# 208  0.011067  (mineral water, milk, ground beef)
# 209  0.010533        (spaghetti, chocolate, eggs)
# 210  0.010933        (spaghetti, chocolate, milk)
#
# [211 rows x 2 columns]

# %%
# selecting and filtering the results
frequent_itemsets = apriori(data, min_support = 0.05, use_colnames=True)
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
frequent_itemsets
# Out:
#      support                    itemsets  length
# 0   0.238267             (mineral water)       1
# 1   0.087200                   (burgers)       1
# 2   0.062533                    (turkey)       1
# 3   0.163867                 (chocolate)       1
# 4   0.095333         (frozen vegetables)       1
# 5   0.174133                 (spaghetti)       1
# 6   0.071333                    (shrimp)       1
# 7   0.052400             (grated cheese)       1
# 8   0.179733                      (eggs)       1
# 9   0.080400                   (cookies)       1
# 10  0.170933              (french fries)       1
# 11  0.098267               (ground beef)       1
# 12  0.068400                  (tomatoes)       1
# 13  0.129600                      (milk)       1
# 14  0.079333                  (escalope)       1
# 15  0.081067                      (cake)       1
# 16  0.132000                 (green tea)       1
# 17  0.095067                  (pancakes)       1
# 18  0.050533                      (soup)       1
# 19  0.065733                 (olive oil)       1
# 20  0.058533          (whole wheat rice)       1
# 21  0.076400            (low fat yogurt)       1
# 22  0.060000                   (chicken)       1
# 23  0.063200           (frozen smoothie)       1
# 24  0.052667  (chocolate, mineral water)       2
# 25  0.059733  (spaghetti, mineral water)       2
# 26  0.050933       (eggs, mineral water)       2

# %%
# getting th item sets with length = 2 and support more han 10%

frequent_itemsets[ (frequent_itemsets['length'] == 2) &
                   (frequent_itemsets['support'] >= 0.01) ]
# Out:
#      support                    itemsets  length
# 24  0.052667  (chocolate, mineral water)       2
# 25  0.059733  (spaghetti, mineral water)       2
# 26  0.050933       (eggs, mineral water)       2

# %%
# getting th item sets with length = 2 and support more han 10%

frequent_itemsets[ (frequent_itemsets['length'] == 1) &
                   (frequent_itemsets['support'] >= 0.01) ]
# Out:
#      support             itemsets  length
# 0   0.238267      (mineral water)       1
# 1   0.087200            (burgers)       1
# 2   0.062533             (turkey)       1
# 3   0.163867          (chocolate)       1
# 4   0.095333  (frozen vegetables)       1
# 5   0.174133          (spaghetti)       1
# 6   0.071333             (shrimp)       1
# 7   0.052400      (grated cheese)       1
# 8   0.179733               (eggs)       1
# 9   0.080400            (cookies)       1
# 10  0.170933       (french fries)       1
# 11  0.098267        (ground beef)       1
# 12  0.068400           (tomatoes)       1
# 13  0.129600               (milk)       1
# 14  0.079333           (escalope)       1
# 15  0.081067               (cake)       1
# 16  0.132000          (green tea)       1
# 17  0.095067           (pancakes)       1
# 18  0.050533               (soup)       1
# 19  0.065733          (olive oil)       1
# 20  0.058533   (whole wheat rice)       1
# 21  0.076400     (low fat yogurt)       1
# 22  0.060000            (chicken)       1
# 23  0.063200    (frozen smoothie)       1

# %%
frequent_itemsets[ frequent_itemsets['itemsets'] == {'eggs', 'mineral water'} ]
# Out:
#      support               itemsets  length
# 26  0.050933  (eggs, mineral water)       2

# %%
frequent_itemsets[ frequent_itemsets['itemsets'] == {'mineral water'} ]
# Out:
#     support         itemsets  length
# 0  0.238267  (mineral water)       1

# %%
frequent_itemsets[ frequent_itemsets['itemsets'] == {'milk'} ]
# Out:
#     support itemsets  length
# 13   0.1296   (milk)       1

# %%
frequent_itemsets[ frequent_itemsets['itemsets'] == {'chicken'} ]
# Out:
#     support   itemsets  length
# 22     0.06  (chicken)       1

# %%
frequent_itemsets[ frequent_itemsets['itemsets'] == {'frozen vegetables'} ]
# Out:
#     support             itemsets  length
# 4  0.095333  (frozen vegetables)       1

# %%
frequent_itemsets[ frequent_itemsets['itemsets'] == {'chocolate'} ]
# Out:
#     support     itemsets  length
# 3  0.163867  (chocolate)       1
